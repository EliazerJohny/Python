# %% [markdown]
# # New Section

# %% [markdown]
# # **Advanced Data types:-**
#
# # **VII. String:-**
# String is a sequence of characters.
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# Mostly strings are immutable but the sub-strings in the strings are mutable.
#
# ```
# a="Hello World"
# print(a)
# print(type(a))
# ```
# ---
# **Index:-**
# An index is used to print a certain characted/element from a group of elements.
#
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string
#
# Index is divided into 2 types:-
#
# 1.  Positive Indexing:-
# In Python, positive zero-based indexing is the fundamental method for accessing iterable items.
# As a result, an index starting at 0 may refer to any element in the iterable.
# The first element in zero-based indexing has an index of 0, the second has an index of 1, and so on.
# It goes from right to left
# ```
# a="Example"
# #  0123456 are the positive index values
# print(a[4]) #out:-p
# ```
# 2.  Negative Indexing:-
# If we wish to print the components starting at the end, we may also use negative indexes. Additionally, by specifying the index number with a negative sign, we may carry out negative tuple indexing (-). As a result, this suggests that the compiler starts thinking about the elements in reverse order, beginning with the element that comes last in the tuple.
# ```
# a="Example"
# print(a[-6]) #out:- x
# print(a[-3]) #out:- p
# ```
#
# **Slicing:-**
# Slicing is used to print a certain group of elements using the index values.
#
# Syntax:- [starting index no.:ending index no.+1]
# ```
# a="Examples"
# print(a[3:7])
# #out:-mple
# #prints from 3 to the 6th elements
# ```
# ```
# a="Examples"
# print(a[-7:-2])
# #out:-xampl
# #prints from -7 to the -3 elements
# ```
#
# **String Operators:-**
# These are of two types:-
# 1.  Concatnation(Union):-String concatenation means add strings together.
#
#   Use the + character to add a variable to another variable:
# ```
# str1="Hello"
# str2="World"
# concat=str1+str2
# #out:-"HelloWorld"
# concat1=str1+" "+str2
# #out:-"Hello World"
# ```
# 2. repetition:-
# Use the multiplication operator (*) to repeat a string a specified number of times.
#
# For example, result = "Hello, world!" * 5 repeats the string "Hello, world!" five times.
#
#
# ```
# a="hello"
# print(a*5)
# #out:-hello hello hello hello hello
# ```
#
# **String Format:-**
#
# 1.  .format() method:-
# The format() method formats the specified value(s) and insert them inside the string's placeholder.
#
# The placeholder is defined using curly brackets: {}. Read more about the placeholders in the Placeholder section below.
#
# The format() method returns the formatted string
# ```
# name="mahi"
# age="21"
# print("My name is {} and i am {} years old".format(name,age))
# #out:-My name is mahi and i am 21 years old
# ```
#
# 2.  f-string method:-
# F-string allows you to format selected parts of a string.
# ```
# name="mahi"
# age=21
# print(f"My name is {name},I am {age} years old")
# ```
#
#
# **String Methods(Function):-**
# Python string is a sequence of Unicode characters that is enclosed in quotation marks. The in-built string functions i.e. the functions provided by Python to operate on strings are:-
# 1.  lower():-Converts all uppercase characters in a string into lowercase
# ```
# a="HeLLo"
# print(a.lower())
# #out:-hello
# ```
#
# 2.  upper():-Converts all uppercase characters in a string into lowercase
# ```
# b="hello"
# print(a.upper())
# #out:-HELLO
# ```
#
# 3.  len():-Used to find the length of the string
# ```
# a="hello world"
# print(len(a))
# #out:-11
# ```
#
# 4. isupper():-Used to know whether the string is in upper case or not.
# Gives the final output in a boolean value.
# ```
# a="HELLO WORLD"
# a.isupper()
# #out:-True
# b="hello world"
# a.isupper()
# #out:-False
# ```
#
# 5.  islower():-Used to know whether the string is in lower case or not.
# Gives the final output in a boolean value.
# ```
# a="HELLO WORLD"
# a.islower()
# #out:-False
# b="hello world"
# a.islower()
# #out:-True
# ```
# 6.  split():-To split a string into a list
# ```
# a="Hello World Example"
# b=a.split()
# print(b)
# #out:-['Hello', 'World', 'Example']
# ```
# 7.  join():- To join a list into a string
# ```
# a=['Hello', 'World', 'Example']
# b=" ".join(a)
# print(b)
# #out:-"Hello World Example"
# ```
# 8. count():- To count the number of time a character is repeated in the given string
# ```
# a="This is a example"
# a.count("e")
# #out:-2
# a.count("T")
# #out:-1
# ```
# 9.  strip():- Removes the whitespace in at the start and the end doesn't remove them in between the string.
# ```
# a="   Hello World      "
# print(a.strip())
# #out:-Hello World
# ```
# 10.  title():-Changes the selecter string into a title
# ```
# a="title"
# print(a.title())
# #out:-Title
# ```
# 11. capitalize() :- Converts the first character to upper case
#
# a = "am good"
# print(a.capitalize())
# #O/P :- "Am good"
#
# 12. casefold() :- Just as lower()
# Converts string into lower case
#
# 13. isalnum() :- Returns true if all the characters in the string are alphanumeric
#
# 14. isalpha():- Returns true if all the characters in the string are alphabets
#
# 15. isdecimal():- Return true if all the characters in the string are decimals.
#
# 16. isdigit():- Returns true if all the characters in the string are digits.
#
# 17. isnumeric():- Returns true if all the chaacters in the string are numbers.
#
# 18. isprintable():- Returns True if all the characters in the stringn are printable
#
# 19. isspace():- Returns True if all the characters in the stringn are white spaces

# %% [markdown]
# # List and its Methods
# List is known as collection of elements/items/values.
#
# It represents with square brackets [] and each element is seperated by 'comma'  ' , '
#
# a=[1,2,3,4,5]
# b=['a','b','c','d','e']
# c=[1.2,3.24,4.3]
# d=[1+5j,8-2j,3+4j]
# e=[True,False,False]
# f=[7,'k',3.54,True,3-3j,'Johny']
# type(a) o/p=lst

# %%
)
